# %% [markdown]
# # <center>Multivariate Regression Example: Public School Budget Breakdown and Poverty Rates</center>
#
# ## Intro
#
# The Census's summary of school finances provides a clear breakdown of school district budgets, showing how much money goes to each of the main categories you would expect in a district budget. This includes things like instruction, infrastructure, support services etc. In this post I'm going to create a multivariate regression model to relate all these categories to district poverty rate. The idea is to better understand how reduced funding in low-income areas is felt in the budget.
#
# ## Imports

# %%
from pydoc import help
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from scipy import stats
from IPython.display import display, HTML

# %% [markdown]
# ## Reading Data

# %%
pov = pd.read_csv('../Data/an_su.csv')
an_su = pd.read_csv('../Data/pov.csv')
descriptions = pd.read_excel('../Data/annual_survey_index.xls')

display(an_su.head(3))
display(pov.head(3))
# Out:
#    Unnamed: 0 State Postal Code  State FIPS Code  District ID  \
# 0           0                AL                1          190
# 1           1                AL                1            5
# 2           2                AL                1           30
#
#                                   Name  Estimated Total Population  \
# 0       alabaster city school district                       32139
# 1     albertville city school district                       21494
# 2  alexander city city school district                       17276
#
#    Estimated Population 5-17  \
# 0                       6502
# 1                       4022
# 2                       2673
#
#    Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder  \
# 0                                                974
# 1                                               1581
# 2                                                961
#
#    poverty_proportion
# 0            0.149800
# 1            0.393088
# 2            0.359521
#    Unnamed: 0       IDCENSUS                            NAME  CONUM  CSA  \
# 0           0  1500100100000  autauga county school district   1001    N
# 1           1  1500200100000  baldwin county school district   1003  380
# 2           2  1500300100000  barbour county school district   1005    N
#
#     CBSA   NCESID  ENROLL  TOTALREV  TFEDREV  ...  PPSALWG  PPEMPBEN  \
# 0  33860  0100240    9609     80867     7447  ...     4478      1886
# 1  19300  0100270   30931    338236    23710  ...     5060      1992
# 2      N  0100300     912     10116     2342  ...     5569      2263
#
#    PPITOTAL  PPISALWG  PPIEMBEN  PPSTOTAL  PPSPUPIL  PPSSTAFF  PPSGENAD  \
# 0      4563      3030      1189      2492       402       231       149
# 1      5332      3360      1263      3143       583       344       123
# 2      5380      3262      1268      4272       565       513       636
#
#    PPSSCHAD
# 0       473
# 1       604
# 2       637
#
# [3 rows x 67 columns]

# %% [markdown]
# ## Data Cleaning and Merging

# %%
an_pov = pd.merge(
    an_su,
    pov,
    left_on="Name",
    right_on="NAME",
    how="inner")

# %% [markdown]
# ## Data Exploration

# %%
display(descriptions)
# Out:
#    Data Item   Summary Table Number, Column   \
# 0   IDCENSUS*                             -
# 1       NAME*                             -
# 2      CONUM*                             -
# 3        CSA*                             -
# 4       CBSA*                             -
# 5     NCESID*                             -
# 6     ENROLL   15, 1 & 16, 1 & 17, 1 & 18, 1
# 7    TOTALREV                          15, 2
# 8     TFEDREV                          15, 3
# 9    FEDRCOMP                          15, 4
# 10   FEDRSPEC                          15, 5
# 11   FEDRNUTR                          15, 6
# 12   FEDROTHR                          15, 7
# 13     TSTREV                          15, 8
# 14    STRFORM                          15, 9
# 15    STRSPEC                         15, 10
# 16   STRTRANS                         15, 11
# 17    STROTHR                         15, 12
# 18    TLOCREV                         15, 13
# 19    LOCRTAX                         15, 14
# 20   LOCRPROP                         15, 15
# 21    LOCRPAR                         15, 16
# 22   LOCRCICO                         15, 17
# 23   LOCROSCH                         15, 18
# 24   LOCRCHAR                         15, 19
# 25   LOCROTHR                         15, 20
# 26   TOTALEXP                          16, 2
# 27   TCURSPND                          16, 3
# 28   TSALWAGE                          16, 4
# 29   TEMPBENE                          16, 5
# ..        ...                            ...
# 36   TCURSGEN                         16, 12
# 37   TCURSSCH                         16, 13
# 38   TCURSOTH                         16, 14
# 39   TCURONON                         16, 15
# 40    TCAPOUT                         16, 16
# 41    TPAYOTH                         16, 17
# 42    TINTRST                         16, 18
# 43    DEBTOUT                              -
# 44   LONGISSU                              -
# 45    LONGRET                              -
# 46   PCTTOTAL                          17, 2
# 47    PCTFTOT                          17, 3
# 48   PCTFCOMP                          17, 4
# 49    PCTSTOT                          17, 5
# 50   PCTSFORM                          17, 6
# 51    PCTLTOT                          17, 7
# 52   PCTLTAXP                          17, 8
# 53   PCTLOTHG                          17, 9
# 54   PCTLCHAR                         17, 10
# 55    PPCSTOT                          18, 2
# 56    PPSALWG                          18, 3
# 57   PPEMPBEN                          18, 4
# 58   PPITOTAL                          18, 5
# 59   PPISALWG                          18, 6
# 60   PPIEMBEN                          18, 7
# 61   PPSTOTAL                          18, 8
# 62   PPSPUPIL                          18, 9
# 63   PPSSTAFF                         18, 10
# 64   PPSGENAD                         18, 11
# 65   PPSSCHAD                         18, 12
#
#                                          Description
# 0                School System Identification Number1
# 1                                 School System Name1
# 2                         ANSI State and County Code1
# 3                      Consolidated Statistical Area1
# 4                        Core-Based Statistical Area1
# 5                         NCES Identification Number1
# 6                                    Fall Membership
# 7                  TOTAL ELEMENTARY-SECONDARY REVENUE
# 8                  Total Revenue from Federal Sources
# 9                              Compensatory (Title I)
# 10                         Children with disabilities
# 11                                Child Nutrition Act
# 12                              All other federal aid
# 13                   Total Revenue from State Sources
# 14                         General formula assistance
# 15                         Special education programs
# 16                            Transportation programs
# 17                            All other state revenue
# 18                   Total Revenue from Local Sources
# 19                                          All taxes
# 20                                     Property taxes
# 21                    Parent government contributions
# 22                   Revenue from cities and counties
# 23                  Revenue from other school systems
# 24                                            Charges
# 25                               Other local revenues
# 26             TOTAL ELEMENTARY-SECONDARY EXPENDITURE
# 27                             Total Current Spending
# 28                           Total salaries and wages
# 29                    Total employee benefit payments
# ..                                                ...
# 36                             General administration
# 37                              School administration
# 38                             Other and nonspecified
# 39                             Other Current Spending
# 40                   Total Capital Outlay Expenditure
# 41                      Payments to Other Governments
# 42             Interest on School System Indebtedness
# 43  Long-term debt outstanding at end of the fisca...
# 44       Long-term debt issued during the fiscal year
# 45      Long-term debt retired during the fiscal year
# 46       PERCENT - TOTAL ELEMENTARY-SECONDARY REVENUE
# 47       Percent - Total Revenue from Federal Sources
# 48                   Percent - Compensatory (Title I)
# 49         Percent - Total Revenue from State Sources
# 50               Percent - General formula assistance
# 51         Percent - Total Revenue from Local Sources
# 52     Percent - Taxes and parent government contr...
# 53     Percent - Revenue from other local governments
# 54                                  Percent - Charges
# 55  Per Pupil - Total Current Spending (Elementary...
# 56               Per Pupil - Total salaries and wages
# 57        Per Pupil - Total employee benefit payments
# 58  Per Pupil - Total Current Spending for Instruc...
# 59                     Per Pupil - Salaries and wages
# 60                      Per Pupil - Employee benefits
# 61  Per Pupil - Total Current Spending for Support...
# 62                          Per Pupil - Pupil support
# 63            Per Pupil - Instructional staff support
# 64                 Per Pupil - General administration
# 65                  Per Pupil - School administration
#
# [66 rows x 3 columns]

# %% [markdown]
# Because we are interested in relating spending on various categories to poverty rates, the main columns to look at are 57 and on:

# %%
display(descriptions.iloc[56:,:])
# Out:
#    Data Item  Summary Table Number, Column   \
# 56    PPSALWG                         18, 3
# 57   PPEMPBEN                         18, 4
# 58   PPITOTAL                         18, 5
# 59   PPISALWG                         18, 6
# 60   PPIEMBEN                         18, 7
# 61   PPSTOTAL                         18, 8
# 62   PPSPUPIL                         18, 9
# 63   PPSSTAFF                        18, 10
# 64   PPSGENAD                        18, 11
# 65   PPSSCHAD                        18, 12
#
#                                          Description
# 56               Per Pupil - Total salaries and wages
# 57        Per Pupil - Total employee benefit payments
# 58  Per Pupil - Total Current Spending for Instruc...
# 59                     Per Pupil - Salaries and wages
# 60                      Per Pupil - Employee benefits
# 61  Per Pupil - Total Current Spending for Support...
# 62                          Per Pupil - Pupil support
# 63            Per Pupil - Instructional staff support
# 64                 Per Pupil - General administration
# 65                  Per Pupil - School administration

# %% [markdown]
# Since this is the focus, let's create a new DF for only those variables as well as the poverty rates and the names of the districts.

# %%
spend_data = an_pov[['Name', 'poverty_proportion'] + list(descriptions['Data Item '][56:].values)]
display(spend_data.head(5))

# save spend_data as an x and y matrix to help with plotting
X = spend_data.poverty_proportion
y = spend_data.loc[:, 'PPSALWG':]

# Create matrix scatter plot of our data
pd.plotting.scatter_matrix(spend_data.loc[:, 'poverty_proportion':], diagonal="kde", figsize=(15, 15))
plt.show()
# Out:
#                                Name  poverty_proportion  PPSALWG  PPEMPBEN  \
# 0  albertville city school district            0.393088     4450      1810
# 1    andalusia city school district            0.324538     4626      1855
# 2     anniston city school district            0.321678     5726      2307
# 3         arab city school district            0.185284     5341      2062
# 4       athens city school district            0.183784     5178      2023
#
#    PPITOTAL  PPISALWG  PPIEMBEN  PPSTOTAL  PPSPUPIL  PPSSTAFF  PPSGENAD  \
# 0      4636      2833      1086      2895       564       288       279
# 1      5283      3230      1240      2976       379       443       323
# 2      6026      3824      1517      4452       657       460       617
# 3      5736      3864      1452      2885       754       191       294
# 4      5566      3447      1324      3347       425       402       354
#
#    PPSSCHAD
# 0       468
# 1       518
# 2       630
# 3       489
# 4       565

# %% [markdown]
# ## Sources
#
# Data from the U.S. Census Bureau:
#
# [Annual Survey of School System Finances](https://www.census.gov/programs-surveys/school-finances.html)
#
# [SAIPE School District Estimates for 2016 ](https://www.census.gov/data/datasets/2016/demo/saipe/2016-school-districts.html)
